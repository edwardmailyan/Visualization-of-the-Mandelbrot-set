# %% [markdown]
# <a href="https://colab.research.google.com/github/edwardmailyan/Visualization-of-the-Mandelbrot-set/blob/main/mandelbrot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# инициализиация
pmin, pmax, qmin, qmax = -2.5, 1.5, -2, 2
# пусть c = p + iq и p меняется в диапазоне от pmin до pmax,
# а q меняется в диапазоне от qmin до qmax

ppoints, qpoints = 500, 500
# число точек по горизонтали и вертикали

# %%
max_iterations = int(input('Введите максимальное число итераций '))
# максимальное количество итераций
# Out:
# Введите максимальное число итераций 500

# %%
infinity_border = int(input('Введите расстояние границы '))
# если ушли на это расстояние, считаем, что ушли на бесконечность
# Out:
# Введите расстояние границы 200

# %%
image = np.zeros((ppoints, qpoints))
# image — это двумерный массив, в котором будет записана наша картинка
# по умолчанию он заполнен нулями

# %%
def mandelbrot(pmin, pmax, ppoints, qmin, qmax, qpoints,
               max_iterations=200, infinity_border=10):
    image = np.zeros((ppoints, qpoints))
    p, q = np.mgrid[pmin:pmax:(ppoints*1j), qmin:qmax:(qpoints*1j)]
    c = p + 1j*q
    z = np.zeros_like(c)
    for k in range(max_iterations):
        z = z**2 + c
        mask = (np.abs(z) > infinity_border) & (image == 0)
        image[mask] = k
        z[mask] = np.nan
    return -image.T

# %%
image = mandelbrot(-2.5, 1.5, 1000, -2, 2, 1000, max_iterations, infinity_border)
plt.figure(figsize=(10, 10))
plt.xticks([])
plt.yticks([])
plt.imshow(image, cmap='flag', interpolation='none')


plt.show();
